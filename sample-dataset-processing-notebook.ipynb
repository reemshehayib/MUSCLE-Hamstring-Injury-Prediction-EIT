# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('downsized_sample_dataset.csv')
df.head()
# Out:
#    rms_feat  integral_signal  zero_crossings  waveform_length  \
# 0  0.181467         2.458629        9.000000        14.999088
# 1  0.091098         1.225373       11.333333         8.493909
# 2  0.115747         1.685769        9.666667        11.712176
# 3  0.078959         1.177512       10.000000         7.179359
# 4  0.074216         1.071029       11.000000         7.232317
#
#    auto_regressive_coefficients  temporal_moment  avg_amp_change  min_value  \
# 0                      0.112136         0.040264        0.072811  -0.173261
# 1                      0.113538         0.005682        0.041033  -0.100648
# 2                      0.110252         0.022562        0.057133  -0.136661
# 3                      0.124593         0.003710        0.035366  -0.086914
# 4                      0.108869         0.003398        0.035280  -0.086399
#
#    max_value  variance  log_detector  linear_env   v_order  modified_mav  \
# 0   0.125012  0.009854      0.045373    0.643452 -0.040235      0.097932
# 1   0.062292  0.002716      0.024587    0.637681 -0.005677      0.049322
# 2   0.079951  0.005886      0.033667    0.625835 -0.022547      0.071522
# 3   0.058312  0.002570      0.029398    0.676005 -0.003698      0.048990
# 4   0.046381  0.001836      0.018263    0.612602 -0.003396      0.040740
#
#    skewness  fourier_series  status
# 0 -2.779578        0.001135       1
# 1 -3.008738        0.000582       0
# 2 -3.327338        0.000819       1
# 3 -2.305951        0.000563       0
# 4 -3.068989        0.000471       1

# %%
print(df.shape)
print(df.isna().sum())
# Out:
# (40000, 17)
# rms_feat                        0
# integral_signal                 0
# zero_crossings                  0
# waveform_length                 0
# auto_regressive_coefficients    0
# temporal_moment                 0
# avg_amp_change                  0
# min_value                       0
# max_value                       0
# variance                        0
# log_detector                    0
# linear_env                      0
# v_order                         0
# modified_mav                    0
# skewness                        0
# fourier_series                  0
# status                          0
# dtype: int64

# %%
# Display summary statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#            rms_feat  integral_signal  zero_crossings  waveform_length  \
# count  40000.000000     40000.000000    40000.000000     40000.000000
# mean       0.112724         1.556219       10.443067        10.568175
# std        0.039976         0.529773        0.879078         3.829018
# min        0.033273         0.488144        8.333333         3.298877
# 25%        0.084332         1.172242       10.000000         7.776551
# 50%        0.104411         1.445156       10.333333         9.753466
# 75%        0.139413         1.925399       11.000000        13.135347
# max        0.243580         3.372757       15.000000        23.120944
#
#        auto_regressive_coefficients  temporal_moment  avg_amp_change  \
# count                  40000.000000     40000.000000    40000.000000
# mean                       0.111407         0.018032        0.051383
# std                        0.007071         0.022424        0.018627
# min                        0.075660         0.000283        0.016014
# 25%                        0.107167         0.004209        0.037802
# 50%                        0.111383         0.008795        0.047401
# 75%                        0.115878         0.023154        0.063881
# max                        0.132324         0.177568        0.112741
#
#           min_value     max_value      variance  log_detector    linear_env  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean      -0.116956      0.073587      0.004759      0.031094      0.632040
# std        0.042135      0.024557      0.003398      0.008742      0.038351
# min       -0.265888      0.023873      0.000408      0.012549      0.456562
# 25%       -0.146562      0.055514      0.002320      0.024491      0.610724
# 50%       -0.106964      0.068861      0.003580      0.029768      0.632545
# 75%       -0.086874      0.090744      0.006549      0.037609      0.650805
# max       -0.040094      0.144355      0.021152      0.058195      0.807603
#
#             v_order  modified_mav      skewness  fourier_series        status
# count  40000.000000  40000.000000  40000.000000    40000.000000  40000.000000
# mean      -0.018017      0.061527     -2.921953        0.000716      0.500000
# std        0.022413      0.021207      0.470575        0.000248      0.500006
# min       -0.177507      0.019891     -4.871898        0.000228      0.000000
# 25%       -0.023133      0.046084     -3.228578        0.000535      0.000000
# 50%       -0.008782      0.056937     -2.950169        0.000659      0.500000
# 75%       -0.004204      0.076430     -2.540543        0.000887      1.000000
# max       -0.000281      0.132829     -1.707215        0.001536      1.000000

# %%
# Plot histograms for all numerical features
df[['rms_feat', 'zero_crossings', 'linear_env', 'modified_mav', 'fourier_series', 'status']].hist(bins=15, figsize=(16, 12), layout=(2, 3))
plt.suptitle('Histograms of Numerical Features')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
