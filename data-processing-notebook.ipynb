# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('merged_file.csv')
df.head()
# Out:
#    rms_feat  integral_signal  zero_crossings  waveform_length  \
# 0  0.127982         1.742839            10.0        11.168069
# 1  0.111467         1.591829             9.0        10.778058
# 2  0.085457         1.211304             9.0         8.211505
# 3  0.092287         1.317333             9.0         8.844116
# 4  0.107735         1.535709             9.0        10.410482
#
#    auto_regressive_coefficients  temporal_moment  avg_amp_change  min_value  \
# 0                      0.100417         0.014920        0.055840  -0.127310
# 1                      0.116953         0.014686        0.052321  -0.118846
# 2                      0.117578         0.006056        0.039862  -0.090266
# 3                      0.118016         0.007840        0.042933  -0.096818
# 4                      0.117408         0.013034        0.050292  -0.114825
#
#    max_value  variance  log_detector  linear_env   v_order  modified_mav  \
# 0   0.078495  0.004633      0.030966    0.615198 -0.014908      0.065112
# 1   0.081719  0.004884      0.031792    0.651916 -0.014675      0.068227
# 2   0.062453  0.002785      0.024771    0.650459 -0.006051      0.051476
# 3   0.068157  0.003276      0.026320    0.658553 -0.007834      0.056409
# 4   0.078692  0.004546      0.030752    0.651277 -0.013025      0.065631
#
#    skewness  fourier_series  status
# 0 -3.163882        0.000785       0
# 1 -2.966115        0.000766       0
# 2 -2.895481        0.000579       0
# 3 -2.904709        0.000624       0
# 4 -2.961475        0.000737       0

# %%
print(df.shape)
print(df.isna().sum())
# Out:
# (40000, 17)
# rms_feat                        0
# integral_signal                 0
# zero_crossings                  0
# waveform_length                 0
# auto_regressive_coefficients    0
# temporal_moment                 0
# avg_amp_change                  0
# min_value                       0
# max_value                       0
# variance                        0
# log_detector                    0
# linear_env                      0
# v_order                         0
# modified_mav                    0
# skewness                        0
# fourier_series                  0
# status                          0
# dtype: int64

# %%
# Display summary statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#            rms_feat  integral_signal  zero_crossings  waveform_length  \
# count  40000.000000     40000.000000    40000.000000     40000.000000
# mean       0.120524         1.658398       10.413983        11.033587
# std        0.034170         0.455513        0.828463         3.085275
# min        0.052441         0.786051        8.333333         5.433538
# 25%        0.093013         1.271577        9.666667         8.416311
# 50%        0.114080         1.577274       10.333333        10.495429
# 75%        0.144002         2.000882       11.000000        13.349013
# max        0.235029         3.226587       14.333333        20.698744
#
#        auto_regressive_coefficients  temporal_moment  avg_amp_change  \
# count                  40000.000000     40000.000000    40000.000000
# mean                       0.112886         0.017509        0.053622
# std                        0.005835         0.015423        0.015005
# min                        0.086448         0.001722        0.026462
# 25%                        0.109037         0.005869        0.040905
# 50%                        0.112529         0.011604        0.050998
# 75%                        0.116648         0.024534        0.064845
# max                        0.128957         0.082240        0.101464
#
#           min_value     max_value      variance  log_detector    linear_env  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean      -0.127122      0.079805      0.005084      0.030980      0.637208
# std        0.035840      0.022127      0.002806      0.007332      0.025379
# min       -0.243115      0.036326      0.001258      0.016519      0.514037
# 25%       -0.153805      0.062499      0.002729      0.024804      0.621411
# 50%       -0.120925      0.075818      0.004271      0.029985      0.635955
# 75%       -0.096771      0.096522      0.006970      0.036876      0.649450
# max       -0.063912      0.138451      0.014626      0.049066      0.738829
#
#             v_order  modified_mav      skewness  fourier_series        status
# count  40000.000000  40000.000000  40000.000000    40000.000000  40000.000000
# mean      -0.017495      0.065555     -2.981920        0.000757      0.500000
# std        0.015413      0.017841      0.288590        0.000213      0.500006
# min       -0.082170      0.034025     -3.831488        0.000375      0.000000
# 25%       -0.024517      0.050051     -3.167341        0.000582      0.000000
# 50%       -0.011592      0.062425     -3.021913        0.000720      0.500000
# 75%       -0.005863      0.079600     -2.823096        0.000915      1.000000
# max       -0.001720      0.111900     -2.269682        0.001359      1.000000

# %%
# Plot histograms for all numerical features
df[['rms_feat', 'zero_crossings', 'linear_env', 'modified_mav', 'fourier_series', 'status']].hist(bins=15, figsize=(12, 16), layout=(3, 2))
plt.suptitle('Histograms of Numerical Features')
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjusts the plot to make room for the title
plt.show()
