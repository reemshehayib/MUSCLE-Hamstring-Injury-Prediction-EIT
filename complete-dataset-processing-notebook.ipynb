# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('MUSCLE_Complete_Dataset.csv')
df.head()
# Out:
#    rms_feat  integral_signal  zero_crossings  waveform_length  \
# 0  0.127982         1.742839            10.0        11.168069
# 1  0.111467         1.591829             9.0        10.778058
# 2  0.085457         1.211304             9.0         8.211505
# 3  0.092287         1.317333             9.0         8.844116
# 4  0.107735         1.535709             9.0        10.410482
#
#    auto_regressive_coefficients  temporal_moment  avg_amp_change  min_value  \
# 0                      0.100417         0.014920        0.055840  -0.127310
# 1                      0.116953         0.014686        0.052321  -0.118846
# 2                      0.117578         0.006056        0.039862  -0.090266
# 3                      0.118016         0.007840        0.042933  -0.096818
# 4                      0.117408         0.013034        0.050292  -0.114825
#
#    max_value  variance  log_detector  linear_env   v_order  modified_mav  \
# ...

# %%
print(df.shape)
print(df.isna().sum())
# Out:
# (120000, 17)
# rms_feat                        0
# integral_signal                 0
# zero_crossings                  0
# waveform_length                 0
# auto_regressive_coefficients    0
# temporal_moment                 0
# avg_amp_change                  0
# min_value                       0
# max_value                       0
# variance                        0
# log_detector                    0
# linear_env                      0
# v_order                         0
# modified_mav                    0
# skewness                        0
# fourier_series                  0
# status                          0
# dtype: int64

# %%
# Display summary statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#             rms_feat  integral_signal  zero_crossings  waveform_length  \
# count  120000.000000    120000.000000   120000.000000    120000.000000
# mean        0.112637         1.555305       10.444414        10.562790
# std         0.039884         0.528396        0.881173         3.819937
# min         0.033273         0.488144        8.333333         3.284500
# 25%         0.084291         1.172879       10.000000         7.785440
# 50%         0.104518         1.448280       10.333333         9.782435
# 75%         0.139288         1.922990       11.000000        13.108515
# max         0.247540         3.372757       15.000000        23.125939
#
#        auto_regressive_coefficients  temporal_moment  avg_amp_change  \
# count                 120000.000000    120000.000000   120000.000000
# mean                       0.111396         0.017973        0.051357
# std                        0.007052         0.022318        0.018581
# ...

# %%
# Plot histograms for all numerical features
df[['rms_feat', 'zero_crossings', 'linear_env', 'modified_mav', 'fourier_series', 'status']].hist(bins=15, figsize=(12, 16), layout=(3, 2))
plt.suptitle('Histograms of Numerical Features')
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjusts the plot to make room for the title
plt.show()
